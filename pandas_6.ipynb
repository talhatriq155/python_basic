# %% [markdown]
# <a href="https://colab.research.google.com/github/talhatriq155/python_basic/blob/master/pandas_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
ml_csv=pd.read_csv('ml.csv')
print(ml_csv)
# Out:
#          brand  colour    sims  memory(kb)  prices
# 0      Samsung   Black    Dual         NaN   250.0
# 1        Apple   White  Single    256000.0   800.0
# 2       Google    Blue    Dual     64000.0   300.0
# 3       Xiaomi     Red    Dual     32000.0   150.0
# 4      OnePlus   Green  Single    128000.0     NaN
# 5     Motorola    Gray    Dual     64000.0   200.0
# 6        Nokia  Yellow  Single     16000.0   100.0
# 7         Sony  Purple    Dual    256000.0   550.0
# 8           LG  Silver  Single     32000.0   180.0
# 9       Huawei    Gold    Dual    128000.0   350.0
# 10        Oppo    Pink    Dual     64000.0   220.0
# 11        Vivo   Brown  Single    256000.0   480.0
# 12      Realme  Orange    Dual     32000.0     NaN
# 13        Asus    Teal  Single    128000.0   380.0
# 14  BlackBerry    Navy    Dual     16000.0    90.0

# %%
# shuffling the rows 1=100% and 0.5=50% data shuffle
ml_csv.sample(frac=1)
# Out:
#          brand  colour    sims  memory(kb)  prices  battery     new
# 6        Nokia  Yellow  Single     16000.0   100.0      2.0   200.0
# 3       Xiaomi     Red    Dual     32000.0   150.0      4.0   600.0
# 0      Samsung   Black    Dual         NaN   250.0      1.0   250.0
# 2       Google    Blue    Dual     64000.0   300.0      3.0   900.0
# 8           LG  Silver  Single     32000.0   180.0      2.0   360.0
# 1        Apple   White  Single    256000.0   800.0      2.0  1600.0
# 13        Asus    Teal  Single    128000.0   380.0      2.0   760.0
# 5     Motorola    Gray    Dual     64000.0   200.0      6.0  1200.0
# 4      OnePlus   Green  Single    128000.0     NaN      5.0     NaN
# 14  BlackBerry    Navy    Dual     16000.0    90.0      2.0   180.0
# 9       Huawei    Gold    Dual    128000.0   350.0      2.0   700.0
# 11        Vivo   Brown  Single    256000.0   480.0      2.0   960.0
# 12      Realme  Orange    Dual     32000.0     NaN      2.0     NaN
# ...

# %%
# reset shuffle
ml_csv.reset_index(drop=True,inplace=True)
ml_csv
# Out:
#          brand  colour    sims  memory(kb)  prices  battery     new
# 0      Samsung   Black    Dual         NaN   250.0      1.0   250.0
# 1        Apple   White  Single    256000.0   800.0      2.0  1600.0
# 2       Google    Blue    Dual     64000.0   300.0      3.0   900.0
# 3       Xiaomi     Red    Dual     32000.0   150.0      4.0   600.0
# 4      OnePlus   Green  Single    128000.0     NaN      5.0     NaN
# 5     Motorola    Gray    Dual     64000.0   200.0      6.0  1200.0
# 6        Nokia  Yellow  Single     16000.0   100.0      2.0   200.0
# 7         Sony  Purple    Dual    256000.0   550.0      2.0  1100.0
# 8           LG  Silver  Single     32000.0   180.0      2.0   360.0
# 9       Huawei    Gold    Dual    128000.0   350.0      2.0   700.0
# 10        Oppo    Pink    Dual     64000.0   220.0      2.0   440.0
# 11        Vivo   Brown  Single    256000.0   480.0      2.0   960.0
# 12      Realme  Orange    Dual     32000.0     NaN      2.0     NaN
# ...

# %%
# convert memory in kbs
# lambda is just store the value
ml_csv=ml_csv['memory(kb)'].apply(lambda x:x/1000)
