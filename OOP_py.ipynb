# %% [markdown]
# <a href="https://colab.research.google.com/github/talhatriq155/python_basic/blob/master/OOP_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class House:
  address:str
  numbers_of_doors:int=2
  numbers_of_rooms:int=4
  def __init__(self,address:str) :

    self.address='house 123'

talha_house=House('house 123')
# hamza_house=House()
# print(f'hamza house adress: {hamza_house.address}')
print(f'talha house number of doors: {talha_house.address}')
# Out:
# talha house number of doors: house 123

# %%
_import matplotlib.pyplot as plt
pd.target.value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='target'>
